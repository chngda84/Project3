# %%
# Dependencies
import pandas as pd

from bs4 import BeautifulSoup
import requests
import pymongo

from sqlalchemy import create_engine
from config import username
from config import password

# %% [markdown]
# # Datasource 1

# %%
# CSV for 1)	Data source 1 – Alphabetical List of Western Australian Schools (XLSX)

# Store CSV into df
csv_file = "Resources/WASchoolsList_cleaned.csv"
WASchools_df = pd.read_csv(csv_file)
WASchools_df.head()
# Out:
#    Code                    School Name                    Street  \
# 0  5001       ADAM ROAD PRIMARY SCHOOL            HOTCHIN STREET
# 1  1463               AL-AMEEN COLLEGE         57 SOUTHGATE ROAD
# 2  1397      AL-HIDAYAH ISLAMIC SCHOOL  CNR HEDLEY ST/NYAMUP WAY
# 3  8001  ALBANY COMMUNITY KINDERGARTEN       136 SERPENTINE ROAD
# 4  5002          ALBANY PRIMARY SCHOOL            SUFFOLK STREET
#
#           Suburb State  Postcode             Postal Street  Postal Suburb  \
# 0  SOUTH BUNBURY    WA      6230            HOTCHIN STREET  SOUTH BUNBURY
# 1       LANGFORD    WA      6147         57 SOUTHGATE ROAD       LANGFORD
# 2        BENTLEY    WA      6102  CNR HEDLEY ST/NYAMUP WAY        BENTLEY
# 3         ALBANY    WA      6330               PO BOX 5670         ALBANY
# 4         ALBANY    WA      6330            SUFFOLK STREET         ALBANY
#
#   Postal State  Postal Postcode  ...   Y06  UPR   Y07   Y08   Y09   Y10   Y11  \
# 0           WA             6230  ...  45.0  NaN   NaN   NaN   NaN   NaN   NaN
# 1           WA             6147  ...  96.0  NaN  83.0  79.0  66.0  67.0  48.0
# 2           WA             6102  ...  24.0  NaN   NaN   NaN   NaN   NaN   NaN
# 3           WA             6332  ...   NaN  NaN   NaN   NaN   NaN   NaN   NaN
# 4           WA             6330  ...  58.0  NaN   NaN   NaN   NaN   NaN   NaN
#
#     Y12  USE  Total Students
# 0   NaN  NaN             446
# 1  45.0  NaN           1,136
# 2   NaN  NaN             202
# 3   NaN  NaN              29
# 4   NaN  NaN             426
#
# [5 rows x 35 columns]

# %%
# look at all the columns available
WASchools_df.columns
# Out:
# Index(['Code', 'School Name', 'Street', 'Suburb', 'State', 'Postcode',
#        'Postal Street', 'Postal Suburb', 'Postal State', 'Postal Postcode',
#        'Latitude', 'Longitude', 'Phone', 'Education Region',
#        'Broad Classification', 'Classification Group', 'Low Year', 'High Year',
#        'KIN', 'PPR', 'Y01', 'Y02', 'Y03', 'Y04', 'Y05', 'Y06', 'UPR', 'Y07',
#        'Y08', 'Y09', 'Y10', 'Y11', 'Y12', 'USE', 'Total Students'],
#       dtype='object')

# %%
# create new data with only relevant columns
new_WASchools_df = WASchools_df[['Classification Group','School Name','Low Year','High Year','Y12','Total Students','Education Region','Latitude','Longitude']].copy()
new_WASchools_df.head()
# Out:
#       Classification Group                    School Name Low Year High Year  \
# 0          PRIMARY SCHOOLS       ADAM ROAD PRIMARY SCHOOL      KIN       Y06
# 1           NON-GOVERNMENT               AL-AMEEN COLLEGE      KIN       Y12
# 2           NON-GOVERNMENT      AL-HIDAYAH ISLAMIC SCHOOL      PPR       Y06
# 3  COMMUNITY KINDERGARTENS  ALBANY COMMUNITY KINDERGARTEN      KIN       KIN
# 4          PRIMARY SCHOOLS          ALBANY PRIMARY SCHOOL      KIN       Y06
#
#     Y12 Total Students    Education Region   Latitude   Longitude
# 0   NaN            446          SOUTH WEST -33.357951  115.635371
# 1  45.0          1,136  SOUTH METROPOLITAN -32.046056  115.937158
# 2   NaN            202  SOUTH METROPOLITAN -32.010358  115.911564
# 3   NaN             29          SOUTH WEST -35.021460  117.880987
# 4   NaN            426          SOUTH WEST -35.018212  117.891611

# %%
# remove instances where Y12 is NaN - i.e. dataset is only for secondary schools with Y12 students in it
nan_value = float("NaN")
new_WASchools_df.replace("", nan_value, inplace=True)
new_WASchools_df.dropna(subset = ["Y12"], inplace=True)

# create id
new_WASchools_df.insert(0, 'School_ID', range(0, 0 + len(new_WASchools_df)))

# rename columns
new_WASchools_df = pd.DataFrame(new_WASchools_df).rename(columns = {'School Name':'School_Name'})
new_WASchools_df = pd.DataFrame(new_WASchools_df).rename(columns = {'Classification Group':'Classification_Group'})

new_WASchools_df.head()
# Out:
#     School_ID Classification_Group                                School_Name  \
# 1           0       NON-GOVERNMENT                           AL-AMEEN COLLEGE
# 5           1    EDUCATION SUPPORT  ALBANY SECONDARY EDUCATION SUPPORT CENTRE
# 6           2    SECONDARY SCHOOLS                  ALBANY SENIOR HIGH SCHOOL
# 8           3       NON-GOVERNMENT                    ALKIMOS BAPTIST COLLEGE
# 12          4       NON-GOVERNMENT                        ALL SAINTS' COLLEGE
#
#    Low Year High Year    Y12 Total Students    Education Region   Latitude  \
# 1       KIN       Y12   45.0          1,136  SOUTH METROPOLITAN -32.046056
# 5       Y07       Y12   17.0             63          SOUTH WEST -34.990749
# 6       Y07       Y12  130.0            958          SOUTH WEST -35.020448
# 8       KIN       Y12   12.0            298  NORTH METROPOLITAN -31.660328
# 12      KIN       Y12  144.0          1,340  SOUTH METROPOLITAN -32.049470
#
#      Longitude
# 1   115.937158
# 5   117.866867
# 6   117.891773
# 8   115.710178
# 12  115.867023

# %%
new_WASchools_df.loc[new_WASchools_df['School_Name'] == "APPLECROSS SENIOR HIGH SCHOOL"]
# Out:
#     School_ID Classification_Group                    School_Name Low Year  \
# 21          6    SECONDARY SCHOOLS  APPLECROSS SENIOR HIGH SCHOOL      Y07
#
#    High Year    Y12 Total Students    Education Region   Latitude  Longitude
# 21       Y12  286.0          1,731  SOUTH METROPOLITAN -32.029376  115.83509

# %% [markdown]
# # Datasource 3

# %%
# <!-- URL for Data source 3 – WA School Ranking – 2020 -->
url = 'https://bettereducation.com.au/results/wa/wace.aspx'

# <!-- read table -->
tables = pd.read_html(url)

# insert table into a df and drop the first column
df_2020 = tables[0].drop(['Unnamed: 0'],axis=1)

# insert year
df_2020['Year'] = 2020

url = 'https://bettereducation.com.au/results/wa/wace.aspx?yr=2019'
tables = pd.read_html(url)
df_2019 = tables[0].drop(['Unnamed: 0'],axis=1)
df_2019['Year'] = 2019

url = 'https://bettereducation.com.au/results/wa/wace.aspx?yr=2018'
tables = pd.read_html(url)
df_2018 = tables[0].drop(['Unnamed: 0'],axis=1)
df_2018['Year'] = 2018

url = 'https://bettereducation.com.au/results/wa/wace.aspx?yr=2017'
tables = pd.read_html(url)
df_2017 = tables[0].drop(['Unnamed: 0'],axis=1)
df_2017['Year'] = 2017

url = 'https://bettereducation.com.au/results/wa/wace.aspx?yr=2016'
tables = pd.read_html(url)
df_2016 = tables[0].drop(['Unnamed: 0'],axis=1)
df_2016['Year'] = 2016

# %%
df= df_2020.append(df_2019).append(df_2018).append(df_2017).append(df_2016)
df
# Out:
#      Better Education Rank                                School  Median ATAR  \
# 0                        1                   Perth Modern School        97.55
# 1                        2  St Hilda's Anglican School for Girls        92.70
# 2                        3          Christ Church Grammar School        92.50
# 3                        4                       Penrhos College        90.65
# 4                        5             Methodist Ladies' College        90.55
# ..                     ...                                   ...          ...
# 138                    139           Thornlie Senior High School        58.45
# 139                    140           Lakeland Senior High School        57.70
# 140                    141       Newton Moore Senior High School        56.95
# 141                    142          Foundation Christian College        50.65
# 142                    143         Warnbro Community High School        45.30
#
#      No. eligible Yr 12 students  No. Students with an ATAR  \
# 0                            242                        242
# 1                            147                        134
# 2                            190                        175
# 3                            135                        116
# 4                            126                        112
# ..                           ...                        ...
# 138                          125                         35
# 139                           89                         27
# 140                           90                         35
# 141                           35                         26
# 142                          171                         48
#
#      % students with an ATAR  Trend / Compare  Year
# 0                     100.00  Trend / Compare  2020
# 1                      91.16  Trend / Compare  2020
# 2                      92.11  Trend / Compare  2020
# 3                      85.93  Trend / Compare  2020
# 4                      88.89  Trend / Compare  2020
# ..                       ...              ...   ...
# 138                    28.00  Trend / Compare  2016
# 139                    30.34  Trend / Compare  2016
# 140                    38.89  Trend / Compare  2016
# 141                    74.29  Trend / Compare  2016
# 142                    28.07  Trend / Compare  2016
#
# [718 rows x 8 columns]

# %%
cols = list(df.columns)
cols
# Out:
# ['Better Education Rank',
#  'School',
#  'Median ATAR',
#  'No. eligible Yr 12 students',
#  'No. Students with an ATAR',
#  '% students with an ATAR',
#  'Trend / Compare',
#  'Year']

# %%
cols = list(df.columns)
# rename columns to something more descriptive 
cols[0] = "ATAR_Ranking"
# rename School to School Name to tie in with Data Source 2
cols[1] = "School_Name"
cols[2] = "Median_ATAR"
cols[3] = "Eligible_Y12_Students"
cols[4] = "Students_with_an_ATAR"
cols[5] = "Pct_students_with_an_ATAR"
cols[6] = "Trend"
cols[7] = "Year"

df.columns = cols

df = df[ ['Year'] + [ col for col in df.columns if col != 'Year' ] ]
# make the school name uppercase to enable easier merge for end user
# df['School_Name'] = df['School_Name'].str.upper()

df.head()
# Out:
#    Year  ATAR_Ranking                           School_Name  Median_ATAR  \
# 0  2020             1                   Perth Modern School        97.55
# 1  2020             2  St Hilda's Anglican School for Girls        92.70
# 2  2020             3          Christ Church Grammar School        92.50
# 3  2020             4                       Penrhos College        90.65
# 4  2020             5             Methodist Ladies' College        90.55
#
#    Eligible_Y12_Students  Students_with_an_ATAR  Pct_students_with_an_ATAR  \
# 0                    242                    242                     100.00
# 1                    147                    134                      91.16
# 2                    190                    175                      92.11
# 3                    135                    116                      85.93
# 4                    126                    112                      88.89
#
#              Trend
# 0  Trend / Compare
# 1  Trend / Compare
# 2  Trend / Compare
# 3  Trend / Compare
# 4  Trend / Compare

# %%
df=df.drop(['Trend'],axis = 1)

# %%
# sort
df = df.sort_values(["ATAR_Ranking", "Year"], ascending = (True, False))
df['School_Name'] = df['School_Name'].str.upper()
print(df)
# Out:
#      Year  ATAR_Ranking                                        School_Name  \
# 0    2020             1                                PERTH MODERN SCHOOL
# 0    2019             1                                PERTH MODERN SCHOOL
# 0    2018             1                                PERTH MODERN SCHOOL
# 0    2017             1                                PERTH MODERN SCHOOL
# 0    2016             1                                PERTH MODERN SCHOOL
# ..    ...           ...                                                ...
# 144  2017           145                             SOUTHERN RIVER COLLEGE
# 145  2018           146                                  DALYELLUP COLLEGE
# 145  2017           146                         HEDLAND SENIOR HIGH SCHOOL
# 146  2018           147                      ROCKINGHAM SENIOR HIGH SCHOOL
# 147  2018           148  WESTERN AUSTRALIAN COLLEGE OF AGRICULTURE (CUN...
#
#      Median_ATAR  Eligible_Y12_Students  Students_with_an_ATAR  \
# 0          97.55                    242                    242
# 0          96.75                    241                    238
# 0          97.00                    240                    236
# 0          95.90                    223                    222
# 0          95.55                    222                    220
# ..           ...                    ...                    ...
# 144        55.40                     96                     24
# 145        51.90                     70                     29
# 145        52.45                     90                     29
# 146        47.90                     98                     22
# 147        32.50                     61                     22
#
#      Pct_students_with_an_ATAR
# 0                       100.00
# 0                        98.76
# 0                        98.33
# 0                        99.55
# 0                        99.10
# ..                         ...
# 144                      25.00
# 145                      41.43
# 145                      32.22
# 146                      22.45
# 147                      36.07
#
# [718 rows x 7 columns]

# %%
# merge in school_id
secondary_schools_df = pd.merge(df, new_WASchools_df, on="School_Name", how = "left")
secondary_schools_df.head()
# Out:
#    Year  ATAR_Ranking          School_Name  Median_ATAR  \
# 0  2020             1  PERTH MODERN SCHOOL        97.55
# 1  2019             1  PERTH MODERN SCHOOL        96.75
# 2  2018             1  PERTH MODERN SCHOOL        97.00
# 3  2017             1  PERTH MODERN SCHOOL        95.90
# 4  2016             1  PERTH MODERN SCHOOL        95.55
#
#    Eligible_Y12_Students  Students_with_an_ATAR  Pct_students_with_an_ATAR  \
# 0                    242                    242                     100.00
# 1                    241                    238                      98.76
# 2                    240                    236                      98.33
# 3                    223                    222                      99.55
# 4                    222                    220                      99.10
#
#    School_ID Classification_Group Low Year High Year    Y12 Total Students  \
# 0      224.0    SECONDARY SCHOOLS      Y07       Y12  247.0          1,447
# 1      224.0    SECONDARY SCHOOLS      Y07       Y12  247.0          1,447
# 2      224.0    SECONDARY SCHOOLS      Y07       Y12  247.0          1,447
# 3      224.0    SECONDARY SCHOOLS      Y07       Y12  247.0          1,447
# 4      224.0    SECONDARY SCHOOLS      Y07       Y12  247.0          1,447
#
#      Education Region   Latitude   Longitude
# 0  NORTH METROPOLITAN -31.945066  115.836396
# 1  NORTH METROPOLITAN -31.945066  115.836396
# 2  NORTH METROPOLITAN -31.945066  115.836396
# 3  NORTH METROPOLITAN -31.945066  115.836396
# 4  NORTH METROPOLITAN -31.945066  115.836396

# %%
# check if there's any bad data that didn't merge
secondary_schools_df[secondary_schools_df['School_ID'].isnull()]
# Out:
#      Year  ATAR_Ranking                                        School_Name  \
# 9    2016             2                       PRESBYTERIAN LADIES' COLLEGE
# 21   2019             5                       PRESBYTERIAN LADIES' COLLEGE
# 39   2017             8                       PRESBYTERIAN LADIES' COLLEGE
# 50   2020            11                       PRESBYTERIAN LADIES' COLLEGE
# 98   2018            20                       PRESBYTERIAN LADIES' COLLEGE
# 121  2016            24              ST STEPHEN'S SCHOOL (CARRAMAR CAMPUS)
# 147  2018            30               AUSTRALIAN ISLAMIC COLLEGE (KEWDALE)
# 148  2017            30                      GREAT SOUTHERN GRAMMAR SCHOOL
# 168  2018            34                     ST STEPHEN'S SCHOOL (CARRAMAR)
# 181  2019            37       CHRISTIAN BROTHERS COLLEGE,FREMANTLE,WA,6160
# 189  2016            38              ST STEPHEN'S SCHOOL (DUNCRAIG CAMPUS)
# 196  2019            40               AUSTRALIAN ISLAMIC COLLEGE (KEWDALE)
# 206  2016            41                      GREAT SOUTHERN GRAMMAR SCHOOL
# 220  2017            44       CHRISTIAN BROTHERS COLLEGE,FREMANTLE,WA,6160
# 237  2016            47                         AUSTRALIAN ISLAMIC COLLEGE
# 242  2020            49       CHRISTIAN BROTHERS COLLEGE,FREMANTLE,WA,6160
# 249  2016            50       CHRISTIAN BROTHERS COLLEGE,FREMANTLE,WA,6160
# 257  2018            52       CHRISTIAN BROTHERS COLLEGE,FREMANTLE,WA,6160
# 305  2020            62           CAREY BAPTIST COLLEGE,HARRISDALE,WA,6112
# 347  2016            69                     PETER MOYES ANGLICAN COMMUNITY
# 370  2016            74                     SWAN VALLEY ANGLICAN COMMUNITY
# 384  2017            77              ST STEPHEN'S SCHOOL (CARRAMAR CAMPUS)
# 423  2017            85              ST STEPHEN'S SCHOOL (DUNCRAIG CAMPUS)
# 473  2018            95                     ST STEPHEN'S SCHOOL (DUNCRAIG)
# 499  2016           100                     IRENE MCCORMACK CATHOLIC COLLE
# 505  2020           102               AUSTRALIAN ISLAMIC COLLEGE (KEWDALE)
# 524  2017           105               AUSTRALIAN ISLAMIC COLLEGE (KEWDALE)
# 613  2017           123                                  WOODTHORPE SCHOOL
# 618  2017           124               SERPENTINE-JARRAHDALE GRAMMAR SCHOOL
# 649  2016           130                                  WOODTHORPE SCHOOL
# 717  2018           148  WESTERN AUSTRALIAN COLLEGE OF AGRICULTURE (CUN...
#
#      Median_ATAR  Eligible_Y12_Students  Students_with_an_ATAR  \
# 9          92.90                    122                    110
# 21         90.75                    123                    116
# 39         89.60                    116                    111
# 50         89.20                    109                     97
# 98         86.90                    127                    115
# 121        85.10                    102                     67
# 147        84.85                     96                     50
# 148        85.00                     83                     59
# 168        84.40                     97                     49
# 181        82.30                    126                     66
# 189        83.15                    145                    118
# 196        81.95                    108                     68
# 206        82.25                     92                     76
# 220        82.15                    129                     72
# 237        81.85                     86                     68
# 242        82.20                    112                     66
# 249        80.70                    128                     78
# 257        81.85                    128                     74
# 305        80.30                    114                     69
# 347        78.45                    133                    106
# 370        77.65                     45                     31
# 384        79.00                     94                     59
# 423        77.40                    123                    111
# 473        76.25                    135                    108
# 499        73.40                    132                     67
# 505        72.55                    131                     83
# 524        73.10                    107                     74
# 613        68.70                     34                     23
# 618        68.40                     55                     31
# 649        64.35                     38                     24
# 717        32.50                     61                     22
#
#      Pct_students_with_an_ATAR  School_ID Classification_Group Low Year  \
# 9                        90.16        NaN                  NaN      NaN
# 21                       94.31        NaN                  NaN      NaN
# 39                       95.69        NaN                  NaN      NaN
# 50                       88.99        NaN                  NaN      NaN
# 98                       90.55        NaN                  NaN      NaN
# 121                      65.69        NaN                  NaN      NaN
# 147                      52.08        NaN                  NaN      NaN
# 148                      71.08        NaN                  NaN      NaN
# 168                      50.52        NaN                  NaN      NaN
# 181                      52.38        NaN                  NaN      NaN
# 189                      81.38        NaN                  NaN      NaN
# 196                      62.96        NaN                  NaN      NaN
# 206                      82.61        NaN                  NaN      NaN
# 220                      55.81        NaN                  NaN      NaN
# 237                      79.07        NaN                  NaN      NaN
# 242                      58.93        NaN                  NaN      NaN
# 249                      60.94        NaN                  NaN      NaN
# 257                      57.81        NaN                  NaN      NaN
# 305                      60.53        NaN                  NaN      NaN
# 347                      79.70        NaN                  NaN      NaN
# 370                      68.89        NaN                  NaN      NaN
# 384                      62.77        NaN                  NaN      NaN
# 423                      90.24        NaN                  NaN      NaN
# 473                      80.00        NaN                  NaN      NaN
# 499                      50.76        NaN                  NaN      NaN
# 505                      63.36        NaN                  NaN      NaN
# 524                      69.16        NaN                  NaN      NaN
# 613                      67.65        NaN                  NaN      NaN
# 618                      56.36        NaN                  NaN      NaN
# 649                      63.16        NaN                  NaN      NaN
# 717                      36.07        NaN                  NaN      NaN
#
#     High Year  Y12 Total Students Education Region  Latitude  Longitude
# 9         NaN  NaN            NaN              NaN       NaN        NaN
# 21        NaN  NaN            NaN              NaN       NaN        NaN
# 39        NaN  NaN            NaN              NaN       NaN        NaN
# 50        NaN  NaN            NaN              NaN       NaN        NaN
# 98        NaN  NaN            NaN              NaN       NaN        NaN
# 121       NaN  NaN            NaN              NaN       NaN        NaN
# 147       NaN  NaN            NaN              NaN       NaN        NaN
# 148       NaN  NaN            NaN              NaN       NaN        NaN
# 168       NaN  NaN            NaN              NaN       NaN        NaN
# 181       NaN  NaN            NaN              NaN       NaN        NaN
# 189       NaN  NaN            NaN              NaN       NaN        NaN
# 196       NaN  NaN            NaN              NaN       NaN        NaN
# 206       NaN  NaN            NaN              NaN       NaN        NaN
# 220       NaN  NaN            NaN              NaN       NaN        NaN
# 237       NaN  NaN            NaN              NaN       NaN        NaN
# 242       NaN  NaN            NaN              NaN       NaN        NaN
# 249       NaN  NaN            NaN              NaN       NaN        NaN
# 257       NaN  NaN            NaN              NaN       NaN        NaN
# 305       NaN  NaN            NaN              NaN       NaN        NaN
# 347       NaN  NaN            NaN              NaN       NaN        NaN
# 370       NaN  NaN            NaN              NaN       NaN        NaN
# 384       NaN  NaN            NaN              NaN       NaN        NaN
# 423       NaN  NaN            NaN              NaN       NaN        NaN
# 473       NaN  NaN            NaN              NaN       NaN        NaN
# 499       NaN  NaN            NaN              NaN       NaN        NaN
# 505       NaN  NaN            NaN              NaN       NaN        NaN
# 524       NaN  NaN            NaN              NaN       NaN        NaN
# 613       NaN  NaN            NaN              NaN       NaN        NaN
# 618       NaN  NaN            NaN              NaN       NaN        NaN
# 649       NaN  NaN            NaN              NaN       NaN        NaN
# 717       NaN  NaN            NaN              NaN       NaN        NaN

# %%
secondary_schools_df = secondary_schools_df.reset_index(drop=True)
secondary_schools_df
# Out:
#      Year  ATAR_Ranking                                        School_Name  \
# 0    2020             1                                PERTH MODERN SCHOOL
# 1    2019             1                                PERTH MODERN SCHOOL
# 2    2018             1                                PERTH MODERN SCHOOL
# 3    2017             1                                PERTH MODERN SCHOOL
# 4    2016             1                                PERTH MODERN SCHOOL
# ..    ...           ...                                                ...
# 713  2017           145                             SOUTHERN RIVER COLLEGE
# 714  2018           146                                  DALYELLUP COLLEGE
# 715  2017           146                         HEDLAND SENIOR HIGH SCHOOL
# 716  2018           147                      ROCKINGHAM SENIOR HIGH SCHOOL
# 717  2018           148  WESTERN AUSTRALIAN COLLEGE OF AGRICULTURE (CUN...
#
#      Median_ATAR  Eligible_Y12_Students  Students_with_an_ATAR  \
# 0          97.55                    242                    242
# 1          96.75                    241                    238
# 2          97.00                    240                    236
# 3          95.90                    223                    222
# 4          95.55                    222                    220
# ..           ...                    ...                    ...
# 713        55.40                     96                     24
# 714        51.90                     70                     29
# 715        52.45                     90                     29
# 716        47.90                     98                     22
# 717        32.50                     61                     22
#
#      Pct_students_with_an_ATAR  School_ID Classification_Group Low Year  \
# 0                       100.00      224.0    SECONDARY SCHOOLS      Y07
# 1                        98.76      224.0    SECONDARY SCHOOLS      Y07
# 2                        98.33      224.0    SECONDARY SCHOOLS      Y07
# 3                        99.55      224.0    SECONDARY SCHOOLS      Y07
# 4                        99.10      224.0    SECONDARY SCHOOLS      Y07
# ..                         ...        ...                  ...      ...
# 713                      25.00      259.0    SECONDARY SCHOOLS      Y07
# 714                      41.43       72.0    SECONDARY SCHOOLS      Y07
# 715                      32.22      123.0    SECONDARY SCHOOLS      Y07
# 716                      22.45      238.0    SECONDARY SCHOOLS      Y07
# 717                      36.07        NaN                  NaN      NaN
#
#     High Year    Y12 Total Students    Education Region   Latitude   Longitude
# 0         Y12  247.0          1,447  NORTH METROPOLITAN -31.945066  115.836396
# 1         Y12  247.0          1,447  NORTH METROPOLITAN -31.945066  115.836396
# 2         Y12  247.0          1,447  NORTH METROPOLITAN -31.945066  115.836396
# 3         Y12  247.0          1,447  NORTH METROPOLITAN -31.945066  115.836396
# 4         Y12  247.0          1,447  NORTH METROPOLITAN -31.945066  115.836396
# ..        ...    ...            ...                 ...        ...         ...
# 713       Y12  116.0            970  SOUTH METROPOLITAN -32.085598  115.979918
# 714       Y12  107.0            749          SOUTH WEST -33.403855  115.625767
# 715       Y12  105.0            999             PILBARA -20.398789  118.598616
# 716       Y12  123.0          1,030  SOUTH METROPOLITAN -32.284952  115.735520
# 717       NaN    NaN            NaN                 NaN        NaN         NaN
#
# [718 rows x 16 columns]

# %%
# replace bad data
# secondary_schools_df['School_Name'] = df['School_Name'].replace(
#     {"PRESBYTERIAN LADIES' COLLEGE":"PRESBYTERIAN LADIES COLLEGE"
#     # ,
#     # "CHRISTIAN BROTHERS COLLEGE,FREMANTLE,WA,6160":"CHRISTIAN BROTHERS' COLLEGE",
#     # "CAREY BAPTIST COLLEGE,HARRISDALE,WA,6112":"CAREY BAPTIST COLLEGE",
#     # "AUSTRALIAN ISLAMIC COLLEGE (KEWDALE)":"AUSTRALIAN ISLAMIC COLLEGE - KEWDALE"
#     })

# %%
# secondary_schools_df[secondary_schools_df['School_ID'].isnull()]
# secondary_schools_df.head()

# %%
# drop School_ID for later remerge for clean data
# secondary_schools_df=secondary_schools_df.drop(["School_ID"],axis=1)
# secondary_schools_df.head()

# %%
# merge in school_id
# secondary_schools_df2 = pd.merge(new_WASchools_df,secondary_schools_df, on="School_Name", how = "right").drop(["Classification_Group","School_Name","Y12"],axis=1)
# secondary_schools_df2.head()

# %%
# check if there's any bad data that didn't merge
# secondary_schools_df2[secondary_schools_df2['School_ID'].isnull()]

# %%
secondary_schools_df
# Out:
#      Year  ATAR_Ranking                                        School_Name  \
# 0    2020             1                                PERTH MODERN SCHOOL
# 1    2019             1                                PERTH MODERN SCHOOL
# 2    2018             1                                PERTH MODERN SCHOOL
# 3    2017             1                                PERTH MODERN SCHOOL
# 4    2016             1                                PERTH MODERN SCHOOL
# ..    ...           ...                                                ...
# 713  2017           145                             SOUTHERN RIVER COLLEGE
# 714  2018           146                                  DALYELLUP COLLEGE
# 715  2017           146                         HEDLAND SENIOR HIGH SCHOOL
# 716  2018           147                      ROCKINGHAM SENIOR HIGH SCHOOL
# 717  2018           148  WESTERN AUSTRALIAN COLLEGE OF AGRICULTURE (CUN...
#
#      Median_ATAR  Eligible_Y12_Students  Students_with_an_ATAR  \
# 0          97.55                    242                    242
# 1          96.75                    241                    238
# 2          97.00                    240                    236
# 3          95.90                    223                    222
# 4          95.55                    222                    220
# ..           ...                    ...                    ...
# 713        55.40                     96                     24
# 714        51.90                     70                     29
# 715        52.45                     90                     29
# 716        47.90                     98                     22
# 717        32.50                     61                     22
#
#      Pct_students_with_an_ATAR  School_ID Classification_Group Low Year  \
# 0                       100.00      224.0    SECONDARY SCHOOLS      Y07
# 1                        98.76      224.0    SECONDARY SCHOOLS      Y07
# 2                        98.33      224.0    SECONDARY SCHOOLS      Y07
# 3                        99.55      224.0    SECONDARY SCHOOLS      Y07
# 4                        99.10      224.0    SECONDARY SCHOOLS      Y07
# ..                         ...        ...                  ...      ...
# 713                      25.00      259.0    SECONDARY SCHOOLS      Y07
# 714                      41.43       72.0    SECONDARY SCHOOLS      Y07
# 715                      32.22      123.0    SECONDARY SCHOOLS      Y07
# 716                      22.45      238.0    SECONDARY SCHOOLS      Y07
# 717                      36.07        NaN                  NaN      NaN
#
#     High Year    Y12 Total Students    Education Region   Latitude   Longitude
# 0         Y12  247.0          1,447  NORTH METROPOLITAN -31.945066  115.836396
# 1         Y12  247.0          1,447  NORTH METROPOLITAN -31.945066  115.836396
# 2         Y12  247.0          1,447  NORTH METROPOLITAN -31.945066  115.836396
# 3         Y12  247.0          1,447  NORTH METROPOLITAN -31.945066  115.836396
# 4         Y12  247.0          1,447  NORTH METROPOLITAN -31.945066  115.836396
# ..        ...    ...            ...                 ...        ...         ...
# 713       Y12  116.0            970  SOUTH METROPOLITAN -32.085598  115.979918
# 714       Y12  107.0            749          SOUTH WEST -33.403855  115.625767
# 715       Y12  105.0            999             PILBARA -20.398789  118.598616
# 716       Y12  123.0          1,030  SOUTH METROPOLITAN -32.284952  115.735520
# 717       NaN    NaN            NaN                 NaN        NaN         NaN
#
# [718 rows x 16 columns]

# %%
secondary_schools_df.to_csv (r'C:\Users\user_491721\Desktop\Analytics Bootcamp\Projects\Project 3\static\schools.csv', index = False, header=True)

# %%
secondary_schools_df.columns
# Out:
# Index(['Year', 'ATAR_Ranking', 'School_Name', 'Median_ATAR',
#        'Eligible_Y12_Students', 'Students_with_an_ATAR',
#        'Pct_students_with_an_ATAR', 'School_ID', 'Classification_Group',
#        'Low Year', 'High Year', 'Y12', 'Total Students', 'Education Region',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
# convert all numeric to string
string_schools_df = secondary_schools_df
string_schools_df['Year'] = string_schools_df['Year'].apply(str)
string_schools_df['ATAR_Ranking'] = string_schools_df['ATAR_Ranking'].apply(str)
string_schools_df['Median_ATAR'] = string_schools_df['Median_ATAR'].apply(str)
string_schools_df['Eligible_Y12_Students'] = string_schools_df['Eligible_Y12_Students'].apply(str)
string_schools_df['Students_with_an_ATAR'] = string_schools_df['Students_with_an_ATAR'].apply(str)
string_schools_df['Pct_students_with_an_ATAR'] = string_schools_df['Pct_students_with_an_ATAR'].apply(str)
string_schools_df['Y12'] = string_schools_df['Y12'].apply(str)
string_schools_df['Total Students'] = string_schools_df['Total Students'].apply(str)
string_schools_df['Latitude'] = string_schools_df['Latitude'].apply(str)
string_schools_df['Longitude'] = string_schools_df['Longitude'].apply(str)

string_schools_df.dtypes
# Out:
# Year                         object
# ATAR_Ranking                 object
# School_Name                  object
# Median_ATAR                  object
# Eligible_Y12_Students        object
# Students_with_an_ATAR        object
# Pct_students_with_an_ATAR    object
# Classification_Group         object
# Low Year                     object
# High Year                    object
# Y12                          object
# Total Students               object
# Education Region             object
# Latitude                     object
# Longitude                    object
# dtype: object

# %%
# Convert to list for data html

school_list = string_schools_df.values.tolist()
print(school_list)
# Out:
# [['2020', '1', 'PERTH MODERN SCHOOL', '97.55', '242', '242', '100.0', 'SECONDARY SCHOOLS', 'Y07', 'Y12', '247.0', '1,447', 'NORTH METROPOLITAN', '-31.94506602', '115.8363958'], ['2019', '1', 'PERTH MODERN SCHOOL', '96.75', '241', '238', '98.76', 'SECONDARY SCHOOLS', 'Y07', 'Y12', '247.0', '1,447', 'NORTH METROPOLITAN', '-31.94506602', '115.8363958'], ['2018', '1', 'PERTH MODERN SCHOOL', '97.0', '240', '236', '98.33', 'SECONDARY SCHOOLS', 'Y07', 'Y12', '247.0', '1,447', 'NORTH METROPOLITAN', '-31.94506602', '115.8363958'], ['2017', '1', 'PERTH MODERN SCHOOL', '95.9', '223', '222', '99.55', 'SECONDARY SCHOOLS', 'Y07', 'Y12', '247.0', '1,447', 'NORTH METROPOLITAN', '-31.94506602', '115.8363958'], ['2016', '1', 'PERTH MODERN SCHOOL', '95.55', '222', '220', '99.1', 'SECONDARY SCHOOLS', 'Y07', 'Y12', '247.0', '1,447', 'NORTH METROPOLITAN', '-31.94506602', '115.8363958'], ['2020', '2', "ST HILDA'S ANGLICAN SCHOOL FOR GIRLS", '92.7', '147', '134', '91.16', 'NON-GOVERNMENT', 'KIN', 'Y12', '129.0', '1,062', 'NORTH METROPOLITAN', '-32.005047', '115.767812'], ['2019', '2', 'HALE SCHOOL', '92.85', '201', '177', '88.06', 'NON-GOVERNMENT', 'PPR', 'Y12', '201.0', '1,582', 'NORTH METROPOLITAN', '-31.91232249', '115.7837828'], ['2018', '2', 'CARMEL SCHOOL', '92.6', '33', '31', '93.94', 'NON-GOVERNMENT', 'KIN', 'Y12', '40.0', '442', 'NORTH METROPOLITAN', '-31.89910743', '115.8620749'], ['2017', '2', "ST HILDA'S ANGLICAN SCHOOL FOR GIRLS", '93.6', '142', '133', '93.66', 'NON-GOVERNMENT', 'KIN', 'Y12', '129.0', '1,062', 'NORTH METROPOLITAN', '-32.005047', '115.767812'], ['2016', '2', "PRESBYTERIAN LADIES' COLLEGE", '92.9', '122', '110', '90.16', nan, nan, nan, 'nan', 'nan', nan, 'nan', 'nan'], ['2020', '3', 'CHRIST CHURCH GRAMMAR SCHOOL', '92.5', '190', '175', '92.11', 'NON-GOVERNMENT', 'KIN', 'Y12', '189.0', '1,717', 'NORTH METROPOLITAN', '-31.98546117', '115.7769868'], ['2019', '3', 'CHRIST CHURCH GRAMMAR SCHOOL', '92.5', '199', '178', '89.45', 'NON-GOVERNMENT', 'KIN', 'Y12', '189.0', '1,717', 'NORTH METROPOLITAN', '-31.98546117', '115.7769868'], ['2018', '3', "ST MARY'S ANGLICAN GIRLS' SCHOOL", '92.1', '175', '150', '85.71', 'NON-GOVERNMENT', 'KIN', 'Y12', '167.0', '1,469', 'NORTH METROPOLITAN', '-31.87697112', '115.766244'], ['2017', '3', 'CHRIST CHURCH GRAMMAR SCHOOL', '92.45', '182', '159', '87.36', 'NON-GOVERNMENT', 'KIN', 'Y12', '189.0', '1,717', 'NORTH METROPOLITAN', '-31.98546117', '115.7769868'], ['2016', '3', 'PENRHOS COLLEGE', '92.65', '145', '123', '84.83', 'NON-GOVERNMENT', 'KIN', 'Y12', '109.0', '936', 'SOUTH METROPOLITAN', '-31.99743072', '115.8725394'], ['2020', '4', 'PENRHOS COLLEGE', '90.65', '135', '116', '85.93', 'NON-GOVERNMENT', 'KIN', 'Y12', '109.0', '936', 'SOUTH METROPOLITAN', '-31.99743072', '115.8725394'], ['2019', '4', "ST MARY'S ANGLICAN GIRLS' SCHOOL", '91.15', '161', '137', '85.09', 'NON-GOVERNMENT', 'KIN', 'Y12', '167.0', '1,469', 'NORTH METROPOLITAN', '-31.87697112', '115.766244'], ['2018', '4', "METHODIST LADIES' COLLEGE", '92.0', '139', '133', '95.68', 'NON-GOVERNMENT', 'KIN', 'Y12', '127.0', '995', 'NORTH METROPOLITAN', '-31.98701169', '115.7755403'], ['2017', '4', 'PENRHOS COLLEGE', '91.2', '139', '119', '85.61', 'NON-GOVERNMENT', 'KIN', 'Y12', '109.0', '936', 'SOUTH METROPOLITAN', '-31.99743072', '115.8725394'], ['2016', '4', 'CHRIST CHURCH GRAMMAR SCHOOL', '92.5', '188', '171', '90.96', 'NON-GOVERNMENT', 'KIN', 'Y12', '189.0', '1,717', 'NORTH METROPOLITAN', '-31.98546117', '115.7769868'], ['2020', '5', "METHODIST LADIES' COLLEGE", '90.55', '126', '112', '88.89', 'NON-GOVERNMENT', 'KIN', 'Y12', '127.0', '995', 'NORTH METROPOLITAN', '-31.98701169', '115.7755403'], ['2019', '5', "PRESBYTERIAN LADIES' COLLEGE", '90.75', '123', '116', '94.31', nan, nan, nan, 'nan', 'nan', nan, 'nan', 'nan'], ['2018', '5', "ST HILDA'S ANGLICAN SCHOOL FOR GIRLS", '91.65', '141', '135', '95.74', 'NON-GOVERNMENT', 'KIN', 'Y12', '129.0', '1,062', 'NORTH METROPOLITAN', '-32.005047', '115.767812'], ['2017', '5', "ST MARY'S ANGLICAN GIR ...

# %% [markdown]
# # LOAD

# %%
rds_connection_string = f"{username}:{password}@localhost:5432/schools_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# check for tables - NOTE this is created in pgadmin before hand
engine.table_names()
# Out:
# <ipython-input-70-2caba68b8947>:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# []

# %%
# note - delete all tables in pg admin schools_db before running the next step

# %%
# NOTE - DON'T RUN MORE THAN ONCE BECUASE IT APPENDS

# Dataset 1
new_WASchools_df2.to_sql(name='wa_schools_y12', con=engine, if_exists='append', index=False)

# Dataset 2
classification_df.to_sql(name='wa_schools_classification', con=engine, if_exists='append', index=False)

# Dataset 3
applecross_df2.to_sql(name='applecross_secondary_schools', con=engine, if_exists='append', index=False)

# Dataset 4
secondary_schools_df2.to_sql(name='secondary_schools_ranking', con=engine, if_exists='append', index=False)

# %%
# confirm Dataset 1 has been added
pd.read_sql_query('select * from wa_schools_y12', con=engine).head()
# Out:
#    School_ID                                School_Name    Y12  \
# 0          0                           AL-AMEEN COLLEGE   45.0
# 1          1  ALBANY SECONDARY EDUCATION SUPPORT CENTRE   17.0
# 2          2                  ALBANY SENIOR HIGH SCHOOL  130.0
# 3          3                    ALKIMOS BAPTIST COLLEGE   12.0
# 4          4                        ALL SAINTS' COLLEGE  144.0
#
#    Classification_ID
# 0                  0
# 1                  1
# 2                  2
# 3                  0
# 4                  0

# %%
# confirm Dataset 2 has been added
pd.read_sql_query('select * from wa_schools_classification', con=engine).head()
# Out:
#    Classification_ID   Classification_Group
# 0                  0         NON-GOVERNMENT
# 1                  1      EDUCATION SUPPORT
# 2                  2      SECONDARY SCHOOLS
# 3                  3           K-12 SCHOOLS
# 4                  4  DISTRICT HIGH SCHOOLS

# %%
# confirm Dataset 3 has been added
pd.read_sql_query('select * from applecross_secondary_schools', con=engine).head()
# Out:
#    School_ID
# 0          6
# 1          7
# 2        244
# 3         63
# 4        188

# %%
# confirm Dataset 4 has been added
pd.read_sql_query('select * from secondary_schools_ranking', con=engine).head()
# Out:
#    School_ID  2020_ATAR_Secondary_School_Ranking  Median_ATAR
# 0        224                                   1        97.55
# 1        266                                   2        92.70
# 2         52                                   3        92.50
# 3        221                                   4        90.65
# 4        192                                   5        90.55
